# %% [markdown]
# <a href="https://colab.research.google.com/github/jegiotimcg-del/School_Projects/blob/main/Expense_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
from datetime import datetime

FILE = "expenses.csv"

def add_expense():
    date = input("Enter date (YYYY-MM-DD) or leave empty for today: ")
    if not date:
        date = str(datetime.today().date())
    item = input("Enter expense item: ")
    amount = float(input("Enter amount: "))

    with open(FILE, "a", newline="") as f:
        writer = csv.writer(f)
        writer.writerow([date, item, amount])
    print("Expense added!")

def view_expenses():
    print("\nDate        Item          Amount")
    print("-"*30)
    try:
        with open(FILE, "r") as f:
            reader = csv.reader(f)
            for row in reader:
                print(f"{row[0]}   {row[1]}    {row[2]}")
    except FileNotFoundError:
        print("No expenses found.")

while True:
    print("\n1. Add Expense  2. View Expenses  3. Exit")
    choice = input("Choose an option: ")
    if choice == "1":
        add_expense()
    elif choice == "2":
        view_expenses()
    elif choice == "3":
        break
    else:
        print("Invalid choice")
# Out:
# 1. Add Expense  2. View Expenses  3. Exit
# Choose an option: 2
#
# Date        Item          Amount
# ------------------------------
# No expenses found.
#
# 1. Add Expense  2. View Expenses  3. Exit
# Choose an option: 1
# Enter date (YYYY-MM-DD) or leave empty for today:
# Enter expense item: 200000
# Enter amount: 200000
# Expense added!
#
# 1. Add Expense  2. View Expenses  3. Exit
# Choose an option: 2
#
# Date        Item          Amount
# ------------------------------
# 2026-02-27   200000    200000.0
#
# 1. Add Expense  2. View Expenses  3. Exit
# Choose an option: 3
