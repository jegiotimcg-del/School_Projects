# %%
import random

words = ["python", "hangman", "programming", "colab", "notebook"]
word = random.choice(words)
guessed = ["_"] * len(word)
attempts = 6

print("=== Hangman Game ===")
while attempts > 0 and "_" in guessed:
    print("Word: " + " ".join(guessed))
    guess = input("Guess a letter: ").lower()

    if guess in word:
        for i, letter in enumerate(word):
            if letter == guess:
                guessed[i] = guess
        print("Correct!")
    else:
        attempts -= 1
        print(f"Wrong! Attempts left: {attempts}")

if "_" not in guessed:
    print(f"Congrats! You guessed the word: {word}")
else:
    print(f"Game over! The word was: {word}")
# Out:
# === Hangman Game ===
# Word: _ _ _ _ _
# Guess a letter: a
# Correct!
# Word: _ _ _ a _
# Guess a letter: s
# Wrong! Attempts left: 5
# Word: _ _ _ a _
# Guess a letter: b
# Correct!
# Word: _ _ _ a b
# Guess a letter: c
# Correct!
# Word: c _ _ a b
# Guess a letter: o
# Correct!
# Word: c o _ a b
# Guess a letter: l
# Correct!
# Congrats! You guessed the word: colab
