# %%
import random

words = ["python", "colab", "game", "computer", "coding", "developer"]

original_word = random.choice(words)
scrambled = list(original_word)
random.shuffle(scrambled)

print("Scrambled word:", "".join(scrambled))

guess = input("Type your answer here 👉 ")

print("You typed:", guess)

if guess.lower().strip() == original_word:
    print("Correct 🎉")
else:
    print("Wrong ❌")
    print("Correct word:", original_word)
# Out:
# Scrambled word: trcupemo
# Type your answer here 👉 scrambled
# You typed: scrambled
# Wrong ❌
# Correct word: computer
